# %% [markdown]
# ## Lab 3: pandas
#
# #### Introduction
#
# We will examine a dataset containing characteristics of lego sets manufactured between 1961 and 2019 from the BRICKSET website. Variables in the dataset are described below.
#
# | VARIABLE             |      DESCRIPTION             |
# |:----------|:-------------|
# | ID |  set id |
# | Name |    name of set   |
# | Themegroup | themegroup of set |
# | Theme |  theme of set |
# | Subtheme |    subtheme of set   |
# | Year | year released |
# | Pieces |  number of pieces |
# | Minifig |    number of minifigs   |
# | Package | type of packaging |
# | Retail_Price |  recommended retail pri
#
#
#
# Load pandas to read in the data and save it as dataframe named lego.

# %%
import pandas as pd

lego = pd.read_csv('C:/Users/amani/Downloads/DataScience/lab-03-Amani-Bara/lego.csv')
lego.head()
lego.sample(15)
# Out:
#               id                                    name     themegroup  \
# 35       30327-1                           My First Duck     Pre-school
# 5803      7732-1                                Air Mail     Modern day
# 5413      6742-1                         Mini Off-Roader   Model making
# 5653     10188-1                              Death Star       Licensed
# 3245     71006-1                      The Simpsons House       Licensed
# 6117      8131-1                           Raceway Rider         Racing
# 5984      4973-1                               Harvester     Pre-school
# 9901      5030-1  Signs for Use with Lighting Bricks 9 V  Miscellaneous
# 620    5005634-1             Skeleton Storage Head Large  Miscellaneous
# 10555     5262-1                             Gear Wheels  Miscellaneous
# 10439      303-1                  Basic Building Set, 3+          Basic
# 1346     71017-6                          Barbara Gordon  Miscellaneous
# 714     71020-19                            Black Canary  Miscellaneous
# 1061     40240-1                                 Raccoon  Miscellaneous
# 7499     26374-1    Bohrok Swarm Trading Game: Blue Pack  Miscellaneous
#
#                          theme                        subtheme    year  \
# 35                       Duplo                             NaN  2019.0
# 5803                      City                           Cargo  2008.0
# 5413                   Creator                             NaN  2009.0
# 5653                 Star Wars       Ultimate Collector Series  2008.0
# 3245              The Simpsons                             NaN  2014.0
# 6117                    Racers                     Tiny Turbos  2007.0
# 5984                     Duplo                      LEGO Ville  2007.0
# 9901             Service Packs                             NaN  1993.0
# 620                       Gear                         Storage  2018.0
# 10555            Service Packs                         Technic  1990.0
# 10439                    Basic                             NaN  1987.0
# 1346   Collectable Minifigures           The LEGO Batman Movie  2017.0
# 714    Collectable Minifigures  The LEGO Batman Movie series 2  2018.0
# 1061               Promotional        Monthly Mini Model Build  2017.0
# 7499                      Gear           Trading/Playing cards  2002.0
#
#        pieces  minifigs    package  retail_price
# 35        NaN         0    Polybag           NaN
# 5803     88.0         1        Box         14.99
# 5413     64.0         0   Canister          5.99
# 5653   3803.0        24        Box        399.99
# 3245   2523.0         6        Box        199.99
# 6117     51.0         0   Canister          4.99
# 5984     11.0         1        NaN         24.99
# 9901     16.0         0    Polybag           NaN
# 620       NaN         0        NaN           NaN
# 10555     9.0         0    Polybag           NaN
# 10439    33.0         0        NaN           NaN
# 1346      7.0         1  Foil pack          3.99
# 714       8.0         1  Foil pack          3.99
# 1061     47.0         0    Polybag           NaN
# 7499      NaN         0        NaN         15.00

# %%
lego.describe()
lego.theme.unique()
lego.theme.value_counts()
# Out:
# theme
# Duplo                        1050
# Town                          640
# Star Wars                     631
# Gear                          585
# Collectable Minifigures       565
#                              ...
# Avatar The Last Airbender       2
# Primo                           2
# The Simpsons                    2
# Boost                           1
# CITY                            1
# Name: count, Length: 139, dtype: int64

# %% [markdown]
# #### Question 1:
# Some sets have missing information for retail_price or pieces or both. This could be because the sets are free (giveaways), they aren’t traditional lego sets (comic books, etc) or just because the information is missing. Filter the lego dataset based on the specifications below and save the result as lego. Hence, you will overwrite the original lego object. In addition, describe the implications of removing these sets.
#
# Your new lego (data frame) should have:
#
# • no missing pieces
#
# • only contain sets with a nonzero number of pieces
#
# • no missing retail_price
#
# • only contain sets with a nonzero retail_price
#
# • no missing year
#
# - Print out the shape of the dataframe after cleaning the dataset.
# -

# %%
 #Drop rows with missing values in 'Pieces', 'Retail_Price', and 'Year'
print(lego.shape)
lego2=lego2.dropna(subset=['pieces', 'retail_price', 'year'])
print(lego2.shape)
# Out:
# (12214, 10)
# (4277, 11)

# %%
#• no missing pieces
#print(lego.shape)
#lego2=lego.dropna() #to drop the missing pieces
#print(lego2.shape)

# %%
#• only contain sets with a nonzero number of pieces
lego2.loc[lego2.pieces>0, : ].shape
# Out:
# (4277, 11)

# %%
#• only contain sets with a nonzero number of pieces
#lego2.loc[lego2.retail_price==0, : ].shape

# %%
#• no missing retail_price
lego2=lego2.loc[lego2.retail_price>0, :] 
lego2.shape
# Out:
# (4277, 11)

# %% [markdown]
# #### Question 2:
# Arrange the dataset in descending order of retail_price and print the first three rows. Report in words the names of the three most expensive lego sets, their prices, and how many pieces each has.

# %%
# Write your answer here
lego2.sort_values(by='retail_price', ascending=False).head(3)
# Out:
#            id                                    name themegroup      theme  \
# 1434  75192-1                       Millennium Falcon   Licensed  Star Wars
# 5944  10179-1  Ultimate Collector's Millennium Falcon   Licensed  Star Wars
# 2065  75159-1                              Death Star   Licensed  Star Wars
#
#                        subtheme    year  pieces  minifigs package  \
# 1434  Ultimate Collector Series  2017.0  7541.0         8     Box
# 5944  Ultimate Collector Series  2007.0  5197.0         5     Box
# 2065  Ultimate Collector Series  2016.0  4016.0        27     Box
#
#       retail_price
# 1434        799.99
# 5944        499.99
# 2065        499.99

# %% [markdown]
# #### Question 3:
#
# It appears that the most expensive sets generally have more pieces. Create a new variable (column) price_per_piece, representing the price in dollars per piece for each of the sets. Save the result as lego2. Hence, you will overwrite the current lego object.

# %%
# Write your answer here

lego2['price_per_piece'] = lego2.retail_price / lego2.pieces
lego2
#lego2.sort_values(by='price_per_piece', ascending=False).head(5)
# Out:
#             id                                         name      themegroup  \
# 1      10264-1                                Corner Garage    Model making
# 2      10265-1                                 Ford Mustang    Model making
# 3      10766-1                                   Woody & RC        Licensed
# 4      10769-1                                  RV Vacation        Licensed
# 5      10770-1               Buzz & Woody's Carnival Mania!        Licensed
# ...        ...                                          ...             ...
# 12082    805-2                             3 Little Indians  Vintage themes
# 12083    806-2                                Cowboy & Pony  Vintage themes
# 12091    520-4  2 X 2 Plate (Flat Roof Bricks with 4 Studs)  Vintage themes
# 12092   7100-1              Samsonite Large Educational Set  Vintage themes
# 12106    215-3                                 2 X 8 Bricks  Vintage themes
#
#                 theme           subtheme    year  pieces  minifigs  \
# 1      Creator Expert  Modular Buildings  2019.0  2569.0         6
# 2      Creator Expert           Vehicles  2019.0  1471.0         0
# 3           Toy Story        Toy Story 4  2019.0    69.0         0
# 4           Toy Story        Toy Story 4  2019.0   178.0         0
# 5           Toy Story        Toy Story 4  2019.0   230.0         0
# ...               ...                ...     ...     ...       ...
# 12082       Samsonite        Model Maker  1964.0    89.0         0
# 12083       Samsonite        Model Maker  1964.0    87.0         0
# 12091       Samsonite       Supplemental  1961.0    40.0         0
# 12092       Samsonite        Educational  1963.0  3250.0         0
# 12106       Samsonite       Supplemental  1961.0     9.0         0
#
#             package  retail_price  price_per_piece
# 1               Box        199.99         0.077847
# 2               Box        149.99         0.101965
# 3               Box          9.99         0.144783
# 4               Box         34.99         0.196573
# 5               Box         49.99         0.217348
# ...             ...           ...              ...
# 12082  Blister pack          0.98         0.011011
# 12083  Blister pack          0.98         0.011264
# 12091           Box          0.50         0.012500
# 12092    Wooden box        100.00         0.030769
# 12106           Box          0.50         0.055556
#
# [4277 rows x 11 columns]

# %% [markdown]
# #### Question 4:
#
# Arrange the lego2 dataset in descending order of price_per_piece and return only the columns: name, themegroup, theme, pieces, price_per_piece, and the first five rows. What do you notice about these sets?

# %%
# Write your answer here
lego3=lego2.sort_values(by='price_per_piece', ascending=False)
lego3=lego3.loc[: , ['name','themegroup','theme', 'pieces', 'price_per_piece'  ]]
lego3.head(5)
# Out:
#                                        name themegroup            theme  \
# 5551               Rechargeable Battery Box  Technical  Power Functions
# 5553                     Transformer 10V DC  Technical  Power Functions
# 5616              Collectable Display Set 2   Licensed        Star Wars
# 8694                     Temperature Sensor  Technical       Mindstorms
# 7540  Robotics Invention System Upgrade Kit  Technical       Mindstorms
#
#       pieces  price_per_piece
# 5551     1.0           49.990
# 5553     1.0           29.990
# 5616     2.0           24.995
# 8694     1.0           24.000
# 7540     1.0           20.000

# %% [markdown]
# #### Question 5:
#
# What is the mean price_per_piece for the top 40 'Toy Story' sets in terms of price_per_piece?

# %%
# Write your answer here
lego3=lego2.sort_values(by='price_per_piece', ascending=False)
lego3.loc[lego3.theme=='Toy Story', :].head(40).price_per_piece.mean()
# Out:
# 0.16089862892544177

# %% [markdown]
# #### Question 6:
#
# What are the unique themes in the lego dataset?

# %%
# Write your answer here
lego2.theme.unique()
lego2.theme.value_counts()
# Out:
# theme
# Star Wars                            498
# Collectable Minifigures              431
# City                                 390
# Town                                 310
# Racers                               183
#                                     ...
# The Lego Movie 2: The Second Part      2
# Explore                                1
# Bricks and More                        1
# Books                                  1
# LEGOLAND                               1
# Name: count, Length: 73, dtype: int64
